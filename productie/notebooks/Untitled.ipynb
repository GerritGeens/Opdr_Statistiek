# %%
import numpy as np 
import matplotlib.pyplot as plt

N = 100000
data = np.random.normal(0,5,N)

plt.hist(data, bins = round(N**(1/2)));

# %%
import pandas as pd

# %%
rows = list ()
for i in range (10): 
    rows.append({"row_number": i, 
                 "random_number": np.random.normal(0,1)*i + 3})
df.loc[7, 'random_number'] = np.nan
    
df = pd.DataFrame(rows)
df.plot(x='row_number', y = 'random_number', marker='o')
# Out:
# <Axes: xlabel='row_number'>
